# %% [markdown]
# # linear regression with single variable
# Today agenda:
#     -linear regression with multiple variable
#     -polynomial regression

# %% [markdown]
# # -+ve linear relation
#   -input and output have incresed viseversa
# --ve linear regression
#   -input and output have decresed viseversa
#
# ##polnomial regression formula
# -y=ax^2+bx+c(for degree=2)
# -y=ax^3+bx^2+cx+1(if degree=3)

# %% [markdown]
# # 1.linear regression with multiple variables
# -input=more than 1 features
# -output= single target
# ##steps for mi
# 1.get or read the data
# 2.data preprocessing or data wargling
# 3.define the input(features)and output(target)
# 4.apply or train the model
# 5.test the model
# 6.evalute metrics (score) for the model

# %% [markdown]
# # import packages
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
###1.read the data 
head_df=pd.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Regression/headbrain.csv")

# %%
head_df
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]

# %%
head_df.columns
# Out:
# Index(['Gender', 'Age Range', 'Head Size(cm^3)', 'Brain Weight(grams)'], dtype='object')

# %%
head_df.head()
# Out:
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
head_df.Gender.unique()
# Out:
# array([1, 2], dtype=int64)

# %%
head_df.['Gender'].value_count()
# Out:
#   File "<ipython-input-16-b9b5931aebd5>", line 1
#     head_df.['Gender'].value_count()
#             ^
# SyntaxError: invalid syntax

# %%
#preprocessing
head_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 4 columns):
# Gender                 237 non-null int64
# Age Range              237 non-null int64
# Head Size(cm^3)        237 non-null int64
# Brain Weight(grams)    237 non-null int64
# dtypes: int64(4)
# memory usage: 7.5 KB

# %%
head.df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-6c12788cbf8b> in <module>
# ----> 1 head.df.isnull().sum()
#
# NameError: name 'head' is not defined

# %%
##3.separate the input and output
input_data=head_df.drop('Brain Weight(grams)',axis=1)
output_data=head_df['Brain Weight(grams)']
input_data.head()
# Out:
#    Gender  Age Range  Head Size(cm^3)
# 0       1          1             4512
# 1       1          1             3738
# 2       1          1             4261
# 3       1          1             3777
# 4       1          1             4177

# %%
input_data.columns
# Out:
# Index(['Gender', 'Age Range', 'Head Size(cm^3)'], dtype='object')

# %%
###4.applying the model
from sklearn.linear_model import LinearRegression
linear=LinearRegression()

# %%
###5.train the model by using fit method
linear.fit(input_data,output_data)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
##6.test the model by using  predict method
pred=linear.predict(input_data)
pred
# Out:
# array([1519.93452386, 1330.91463003, 1458.63737483, 1340.43888825,
#        1438.1235879 , 1293.55023241, 1342.39258224, 1287.20072693,
#        1300.38816139, 1390.50229682, 1258.87216403, 1393.18862606,
#        1306.98187861, 1445.69415212, 1353.87053445, 1364.61585141,
#        1272.05959849, 1264.48903426, 1173.88647533, 1498.44388994,
#        1365.10427491, 1406.13184876, 1347.03260547, 1324.07670105,
#        1577.32428491, 1498.19967819, 1403.68973127, 1400.27076679,
#        1261.55849328, 1437.6351644 , 1342.88100574, 1345.07891148,
#        1420.05191847, 1434.21619992, 1433.48356467, 1349.47472296,
#        1279.38595096, 1333.35674752, 1232.25308338, 1270.83853974,
#        1385.61806184, 1274.01329248, 1471.82480928, 1347.03260547,
#        1361.44109867, 1403.20130777, 1470.11532704, 1190.98129777,
#        1307.22609036, 1307.95872561, 1368.27902765, 1344.34627623,
#        1460.83528057, 1410.2834485 , 1397.82864929, 1262.53534027,
# ...

# %%
###evalute the model
linear.score(input_data,output_data)*100
# Out:
# 65.28346387526655

# %%
head_df['Head']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-4d6ba58ecda9> in <module>
#       1 ##predict manually
# ----> 2 linear.predict()
#
# TypeError: predict() missing 1 required positional argument: 'X'

# %%
##predict manually
linear.predict([[1,2,5000]])
# Out:
# array([1615.14141201])

# %%
head_df.head(1)
# Out:
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530

# %%
linear.predict([[1,1,4512]])###predict with 1 row
# Out:
# array([1519.93452386])

# %%
linear.coef_
# Out:
# array([-22.5432537 , -23.96844543,   0.24421175])

# %%
linear.intercept_
# Out:
# 464.5628108859038

# %%
##y=mx+c

# %%
###linear regression with applestore.csv

# %%
apple_df=pd.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Regression/AppleStore.csv")
apple_df.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
apple_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7197 entries, 0 to 7196
# Data columns (total 17 columns):
# Unnamed: 0          7197 non-null int64
# id                  7197 non-null int64
# track_name          7197 non-null object
# size_bytes          7197 non-null int64
# currency            7197 non-null object
# price               7197 non-null float64
# rating_count_tot    7197 non-null int64
# rating_count_ver    7197 non-null int64
# user_rating         7197 non-null float64
# user_rating_ver     7197 non-null float64
# ver                 7197 non-null object
# cont_rating         7197 non-null object
# prime_genre         7197 non-null object
# sup_devices.num     7197 non-null int64
# ipadSc_urls.num     7197 non-null int64
# lang.num            7197 non-null int64
# vpp_lic             7197 non-null int64
# dtypes: float64(3), int64(9), object(5)
# memory usage: 956.0+ KB

# %%
from sklearn.preprocessing import LabelEncoder
lbr=LabelEncoder()

# %%
apple_df['currency']=lbr.fit_transform(apple_df['currency'])
apple_df['ver']=lbr.fit_transform(apple_df['ver'])
apple_df['cont_rating']=lbr.fit_transform(apple_df['cont_rating'])
apple_df['prime_genre']=lbr.fit_transform(apple_df['prime_genre'])

# %%
apple_df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'track_name', 'size_bytes', 'currency', 'price',
#        'rating_count_tot', 'rating_count_ver', 'user_rating',
#        'user_rating_ver', 'ver', 'cont_rating', 'prime_genre',
#        'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic'],
#       dtype='object')

# %%
apple_df.drop(['Unnamed: 0','track_name'],axis=1,inplace=True)
apple_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-7e7fe3d76451> in <module>
# ----> 1 apple_df.drop(['Unnamed: 0','track_name'],axis=1,inplace=True)
#       2 apple_df.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
apple_df.head()
# Out:
#           id  size_bytes  currency  price  rating_count_tot  rating_count_ver  \
# 0  281656475   100788224         0   3.99             21292                26
# 1  281796108   158578688         0   0.00            161065                26
# 2  281940292   100524032         0   0.00            188583              2822
# 3  282614216   128512000         0   0.00            262241               649
# 4  282935706    92774400         0   0.00            985920              5320
#
#    user_rating  user_rating_ver   ver  cont_rating  prime_genre  \
# 0          4.0              4.5  1379            2            7
# 1          4.0              3.5  1514            2           15
# 2          3.5              4.5  1210            2           22
# 3          4.0              4.5  1236            0           17
# 4          4.5              5.0  1472            2           16
#
#    sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0               38                5        10        1
# ...

# %%
apple_df.columns
# Out:
# Index(['id', 'size_bytes', 'currency', 'price', 'rating_count_tot',
#        'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver',
#        'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num',
#        'lang.num', 'vpp_lic'],
#       dtype='object')

# %%
x=apple_df.drop('price',axis=1)
y=apple_df['price']

# %%
import seaborn as sns
sns.pairplot(apple_df)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=lr.predict(x)

# %%
from sklearn.metrics import r2_score
r2_score(y,y_pred)*100
# Out:
# 5.93489219270531
